# %% [markdown]
# ## Question 1

# %%
import numpy as np
def f(x):
    return x**2-2
a = 1
b = 2
c = (a+b)/2
print('i \t a \t \t b \t \t c=(a+b)/2 \t f(a) \t \t \t f(b) \t \t \t f(c) ')
for i in range(10):
    if(0<=i<=1):
        print(i,'\t',a,'\t \t',b,'\t \t', c,'\t \t',f(a),'\t \t \t',f(b),'\t \t \t',f(c))
    elif(i==2):
        print(i,'\t',a,'\t \t',b,'\t \t', c,'\t \t',f(a),'\t \t',f(b),'\t \t \t',f(c))
    elif(i==3):
        print(i,'\t',a,'\t \t',b,'\t \t', c,'\t',f(a),'\t \t',f(b),'\t \t \t',f(c))
    elif(i == 4):
        print(i,'\t',a,'\t \t',b,'\t', c,'\t',f(a),'\t \t', f(b),'\t \t', f(c))
    elif(i==5):
        print(i,'\t',a,'\t',b,'\t', c,'\t',f(a),'\t \t',f(b),'\t \t',f(c))
    elif(i==6):
        print(i,'\t',a,'\t',b,'\t', c,'\t',f(a),'\t \t',f(b),'\t',f(c))
    else:
        print(i,'\t',a,'\t',b,'\t', c,'\t',f(a),'\t',f(b),'\t',f(c))
    if f(a)*f(c) < 0:
       # a = a
        b = c
    else:
        a = c
       # b = b
    c = (a+b)/2
# Out:
# i 	 a 	 	 b 	 	 c=(a+b)/2 	 f(a) 	 	 	 f(b) 	 	 	 f(c)
# 0 	 1 	 	 2 	 	 1.5 	 	 -1 	 	 	 2 	 	 	 0.25
# 1 	 1 	 	 1.5 	 	 1.25 	 	 -1 	 	 	 0.25 	 	 	 -0.4375
# 2 	 1.25 	 	 1.5 	 	 1.375 	 	 -0.4375 	 	 0.25 	 	 	 -0.109375
# 3 	 1.375 	 	 1.5 	 	 1.4375 	 -0.109375 	 	 0.25 	 	 	 0.06640625
# 4 	 1.375 	 	 1.4375 	 1.40625 	 -0.109375 	 	 0.06640625 	 	 -0.0224609375
# 5 	 1.40625 	 1.4375 	 1.421875 	 -0.0224609375 	 	 0.06640625 	 	 0.021728515625
# 6 	 1.40625 	 1.421875 	 1.4140625 	 -0.0224609375 	 	 0.021728515625 	 -0.00042724609375
# 7 	 1.4140625 	 1.421875 	 1.41796875 	 -0.00042724609375 	 0.021728515625 	 0.0106353759765625
# 8 	 1.4140625 	 1.41796875 	 1.416015625 	 -0.00042724609375 	 0.0106353759765625 	 0.005100250244140625
# 9 	 1.4140625 	 1.416015625 	 1.4150390625 	 -0.00042724609375 	 0.005100250244140625 	 0.0023355484008789062

# %%
def f(x):
    return x**2-2
print(f(1.4150390625))
# Out:
# 0.0023355484008789062

# %% [markdown]
# ## Question 2

# %%
def f(x):
    return x**2-2
a = 1
b = 2
c = (a+b)/2
tol = 10**(-7)
i=0
temp=b
while(abs(temp-c) > tol):
    temp=c
    if f(a)*f(c) < 0:
        b = c
    else:
        a = c
    c = (a+b)/2
    i = i+1
    list = [i,a,b,c]
    print(list)
# Out:
# [1, 1, 1.5, 1.25]
# [2, 1.25, 1.5, 1.375]
# [3, 1.375, 1.5, 1.4375]
# [4, 1.375, 1.4375, 1.40625]
# [5, 1.40625, 1.4375, 1.421875]
# [6, 1.40625, 1.421875, 1.4140625]
# [7, 1.4140625, 1.421875, 1.41796875]
# [8, 1.4140625, 1.41796875, 1.416015625]
# [9, 1.4140625, 1.416015625, 1.4150390625]
# [10, 1.4140625, 1.4150390625, 1.41455078125]
# [11, 1.4140625, 1.41455078125, 1.414306640625]
# [12, 1.4140625, 1.414306640625, 1.4141845703125]
# [13, 1.4141845703125, 1.414306640625, 1.41424560546875]
# [14, 1.4141845703125, 1.41424560546875, 1.414215087890625]
# [15, 1.4141845703125, 1.414215087890625, 1.4141998291015625]
# [16, 1.4141998291015625, 1.414215087890625, 1.4142074584960938]
# [17, 1.4142074584960938, 1.414215087890625, 1.4142112731933594]
# [18, 1.4142112731933594, 1.414215087890625, 1.4142131805419922]
# [19, 1.4142131805419922, 1.414215087890625, 1.4142141342163086]
# [20, 1.4142131805419922, 1.4142141342163086, 1.4142136573791504]
# ...

# %%
def f(x):
    return x**2-2
a = 1
b = 2
c = (a+b)/2
tol = 10**(-7)
i=0
rem=b
while(abs((rem-c)/rem) > tol):
    rem=c
    if f(a)*f(c) < 0:
        b = c
    else:
        a = c
    c = (a+b)/2
    i = i+1
    list = [i,a,b,c]
    print(list)
# Out:
# [1, 1, 1.5, 1.25]
# [2, 1.25, 1.5, 1.375]
# [3, 1.375, 1.5, 1.4375]
# [4, 1.375, 1.4375, 1.40625]
# [5, 1.40625, 1.4375, 1.421875]
# [6, 1.40625, 1.421875, 1.4140625]
# [7, 1.4140625, 1.421875, 1.41796875]
# [8, 1.4140625, 1.41796875, 1.416015625]
# [9, 1.4140625, 1.416015625, 1.4150390625]
# [10, 1.4140625, 1.4150390625, 1.41455078125]
# [11, 1.4140625, 1.41455078125, 1.414306640625]
# [12, 1.4140625, 1.414306640625, 1.4141845703125]
# [13, 1.4141845703125, 1.414306640625, 1.41424560546875]
# [14, 1.4141845703125, 1.41424560546875, 1.414215087890625]
# [15, 1.4141845703125, 1.414215087890625, 1.4141998291015625]
# [16, 1.4141998291015625, 1.414215087890625, 1.4142074584960938]
# [17, 1.4142074584960938, 1.414215087890625, 1.4142112731933594]
# [18, 1.4142112731933594, 1.414215087890625, 1.4142131805419922]
# [19, 1.4142131805419922, 1.414215087890625, 1.4142141342163086]
# [20, 1.4142131805419922, 1.4142141342163086, 1.4142136573791504]
# ...

# %%
def f(x):
    return x**2-2
a = 1
b = 2
c = (a+b)/2
tol = 10**(-7)
i=0
while(abs(f(c)) > tol):
    if f(a)*f(c) < 0:
        b = c
    else:
        a = c
    c = (a+b)/2
    i = i+1
    list = [i,a,b,c]
    print(list)
# Out:
# [1, 1, 1.5, 1.25]
# [2, 1.25, 1.5, 1.375]
# [3, 1.375, 1.5, 1.4375]
# [4, 1.375, 1.4375, 1.40625]
# [5, 1.40625, 1.4375, 1.421875]
# [6, 1.40625, 1.421875, 1.4140625]
# [7, 1.4140625, 1.421875, 1.41796875]
# [8, 1.4140625, 1.41796875, 1.416015625]
# [9, 1.4140625, 1.416015625, 1.4150390625]
# [10, 1.4140625, 1.4150390625, 1.41455078125]
# [11, 1.4140625, 1.41455078125, 1.414306640625]
# [12, 1.4140625, 1.414306640625, 1.4141845703125]
# [13, 1.4141845703125, 1.414306640625, 1.41424560546875]
# [14, 1.4141845703125, 1.41424560546875, 1.414215087890625]
# [15, 1.4141845703125, 1.414215087890625, 1.4141998291015625]
# [16, 1.4141998291015625, 1.414215087890625, 1.4142074584960938]
# [17, 1.4142074584960938, 1.414215087890625, 1.4142112731933594]
# [18, 1.4142112731933594, 1.414215087890625, 1.4142131805419922]
# [19, 1.4142131805419922, 1.414215087890625, 1.4142141342163086]
# [20, 1.4142131805419922, 1.4142141342163086, 1.4142136573791504]
# ...

# %%
print(a)
# Out:
# 1.4142134189605713
