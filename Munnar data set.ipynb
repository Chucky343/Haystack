# %%
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\Study Materials\Internship\Project 1_Analytics Project_Munnar Data Set-20240313T141325Z-001\Project 1_Analytics Project_Munnar Data Set\Data Analyst munnar Dataset.csv")
df.head(20)
# Out:
#                          Hotel Name\t\t\t\t\t\t\t\t\t  Rating  \
# 0                                        Gokulam Park     4.1
# 1                                     Sterling Munnar     3.8
# 2                                    Issacs Residency     4.1
# 3                                   Tea Valley Resort     4.3
# 4                                         Grand Plaza     4.3
# 5                               Misty Mountain Resort     4.2
# 6                                      Eastend Munnar     3.9
# 7                     Seven Springs Plantation Resort     3.7
# 8                         Clouds Valley Leisure Hotel     4.0
# 9                             Broad Bean Resort & Spa     4.1
# 10                                    KTDC Tea County     4.4
# 11                            Parakkat Nature Resorts     4.3
# 12  Chithirapuram Palace | Rooms & Restaurant\nLik...     4.5
# 13        Devonshire Greens - The Leisure Hotel & Spa     3.9
# 14                                    Sn Holiday Home     4.2
# 15                                        Vibe Munnar     4.6
# 16           Landy Queen Homestay | Rooms & Caretaker     4.5
# 17                               juSTa Rangers Munnar     4.2
# 18                              The Panoramic Getaway     4.6
# 19                                     Hotel Hillview     3.9
#
#    Rating Description  Reviews  Star Rating                Location  \
# 0           Very Good     1058          4.0          Chithirapuram
# 1           Very Good     1088          4.0            Chinnakanal
# 2           Very Good      322          3.0         Central Munnar
# 3           Excellent     1337          4.0             Pallivasal
# 4           Excellent     1058          4.0             Moolakadai
# 5           Very Good     1934          4.0             Pallivasal
# 6           Very Good      437          4.0         Central Munnar
# 7           Very Good        6          3.0           Laxmi Estate
# 8           Very Good      599          4.0  Near Munnar Bus Stand
# 9           Very Good      249          5.0   Muthirapuzhayar Road
# 10          Excellent      851          4.0         Central Munnar
# 11          Excellent     1310          5.0             Pallivasal
# 12          Excellent       96          NaN          Chithirapuram
# 13          Very Good      431          5.0             Pallivasal
# 14          Very Good      369          NaN                Anachal
# 15          Excellent      136          5.0          Ettycity Road
# 16          Excellent      188          NaN         Central Munnar
# 17          Very Good      188          4.0                Adimali
# 18          Excellent      939          5.0          Chithirapuram
# 19          Very Good      501          4.0             Moolakadai
#
#       Nearest Landmark Distance to Landmark   Price    Tax
# 0          city centre             10.2 km    2,728    574
# 1          city centre             19.2 km    4,451    969
# 2   Attukal Waterfalls               950 m    2,758    684
# 3          city centre              4.8 km    2,675    756
# 4   Attukal Waterfalls              1.9 km    3,203    654
# 5          city centre              7.5 km    3,145    848
# 6   Attukal Waterfalls               770 m    3,493    713
# 7          city centre             12.3 km    2,255    554
# 8   Attukal Waterfalls              2.2 km    2,595    530
# 9          city centre             13.1 km    5,583  1,141
# 10  Attukal Waterfalls              1.7 km    5,022  1,026
# 11         city centre              7.8 km    9,977  2,682
# 12         city centre             10.8 km    2,494    634
# 13         city centre              5.9 km    4,815  1,177
# 14         city centre             11.1 km      966    229
# 15         city centre             13.1 km    7,905  2,380
# 16  Attukal Waterfalls              1.1 km    1,279    269
# 17         city centre             23.8 km    3,481    946
# 18         city centre              9.8 km   11,974  4,617
# 19  Attukal Waterfalls              2.5 km    2,820    693

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['Hotel Name\t\t\t\t\t\t\t\t\t', 'Rating', 'Rating Description',
#        'Reviews', 'Star Rating', 'Location', 'Nearest Landmark',
#        'Distance to Landmark', 'Price', 'Tax'],
#       dtype='object')
# (74, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name									   74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           57 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     object
#  8   Price                 74 non-null     object
#  9   Tax                   72 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 5.9+ KB

# %%
print(sys.getsizeof(df)) ## to see how much ram will be required to run the dataset
# Out:
# 36974

# %%
df.rename(columns = {'Hotel Name\t\t\t\t\t\t\t\t\t':'Hotel Name'}, inplace = True)
df.head()
# Out:
#           Hotel Name  Rating Rating Description  Reviews  Star Rating  \
# 0       Gokulam Park     4.1          Very Good     1058          4.0
# 1    Sterling Munnar     3.8          Very Good     1088          4.0
# 2   Issacs Residency     4.1          Very Good      322          3.0
# 3  Tea Valley Resort     4.3          Excellent     1337          4.0
# 4        Grand Plaza     4.3          Excellent     1058          4.0
#
#           Location    Nearest Landmark Distance to Landmark  Price  Tax
# 0   Chithirapuram          city centre             10.2 km   2,728  574
# 1     Chinnakanal          city centre             19.2 km   4,451  969
# 2  Central Munnar   Attukal Waterfalls               950 m   2,758  684
# 3      Pallivasal          city centre              4.8 km   2,675  756
# 4      Moolakadai   Attukal Waterfalls              1.9 km   3,203  654

# %%
df.index = df['Hotel Name']

# %%
print(df.loc['Vibe Munnar'])
print(df.iloc[7])
# Out:
# Hotel Name                 Vibe Munnar
# Rating                             4.6
# Rating Description           Excellent
# Reviews                            136
# Star Rating                        5.0
# Location                Ettycity Road
# Nearest Landmark           city centre
# Distance to Landmark          13.1 km
# Price                            7,905
# Tax                              2,380
# Name: Vibe Munnar, dtype: object
# Hotel Name              Seven Springs Plantation Resort
# Rating                                              3.7
# Rating Description                            Very Good
# Reviews                                               6
# Star Rating                                         3.0
# Location                                  Laxmi Estate
# Nearest Landmark                            city centre
# Distance to Landmark                           12.3 km
# Price                                             2,255
# Tax                                                 554
# Name: Seven Springs Plantation Resort, dtype: object

# %%
print(type(df.loc['Vibe Munnar']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.reset_index(inplace = True, drop = True)
df.head(2)
# Out:
#         Hotel Name  Rating Rating Description  Reviews  Star Rating  \
# 0     Gokulam Park     4.1          Very Good     1058          4.0
# 1  Sterling Munnar     3.8          Very Good     1088          4.0
#
#          Location Nearest Landmark Distance to Landmark  Price  Tax
# 0  Chithirapuram       city centre             10.2 km   2,728  574
# 1    Chinnakanal       city centre             19.2 km   4,451  969

# %%
df.nunique()
# Out:
# Hotel Name              74
# Rating                  18
# Rating Description       4
# Reviews                 70
# Star Rating              4
# Location                22
# Nearest Landmark         2
# Distance to Landmark    57
# Price                   72
# Tax                     70
# dtype: int64

# %%
from timeit import default_timer as timer
start = timer()
df.info()
print(timer()-start)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           57 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     object
#  8   Price                 74 non-null     object
#  9   Tax                   72 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 5.9+ KB
# 0.00399480000010044

# %%
start = timer()
df['Star Rating'].isna().sum() ## get how many null values exist
print(timer() - start)
# Out:
# 0.0004335000000992295

# %%
print(type(df['Price'].iloc[0]))
df['Price'] = df['Price'].apply(lambda x: str(x))
df['Price'] = df['Price'].apply(lambda x: x.replace(",",""))
df['Price'] = df['Price'].astype('float64')  ## changing data types by some preprocessing        
df['Price']
# Out:
# <class 'str'>
# 0     2728.0
# 1     4451.0
# 2     2758.0
# 3     2675.0
# 4     3203.0
#        ...
# 69    8103.0
# 70    3317.0
# 71    3953.0
# 72    6862.0
# 73    1014.0
# Name: Price, Length: 74, dtype: float64

# %%
## use similar methods for other object data types
print(type(df['Price'].iloc[0]))
df['Price'] = df['Price'].apply(lambda x: str(x))
df['Price'] = df['Price'].apply(lambda x: x.replace(",",""))
df['Price'] = df['Price'].astype('float64')  ## changing data types by some preprocessing        
df['Price']
# Out:
# <class 'numpy.float64'>
# 0     2728.0
# 1     4451.0
# 2     2758.0
# 3     2675.0
# 4     3203.0
#        ...
# 69    8103.0
# 70    3317.0
# 71    3953.0
# 72    6862.0
# 73    1014.0
# Name: Price, Length: 74, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           57 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     object
#  8   Price                 74 non-null     float64
#  9   Tax                   72 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 5.9+ KB

# %%
df['unit'] = df['Distance to Landmark'].apply(lambda x: x.split()[1])

# %%
df['unit']
# Out:
# 0     km
# 1     km
# 2      m
# 3     km
# 4     km
#       ..
# 69    km
# 70    km
# 71    km
# 72    km
# 73    km
# Name: unit, Length: 74, dtype: object

# %%
(df['unit'] == 'm').sum()
# Out:
# 4

# %%
def change_unit(x):
    if x.split()[1] == 'm':
        return float(x.split()[0])/1000
    else:
        return x.split()[0]

# %%
df['Distance to Landmark'] = df['Distance to Landmark'].apply(change_unit)
df['Distance to Landmark']
# Out:
# 0     10.2
# 1     19.2
# 2     0.95
# 3      4.8
# 4      1.9
#       ...
# 69    13.2
# 70    20.6
# 71     5.8
# 72     6.6
# 73     1.3
# Name: Distance to Landmark, Length: 74, dtype: object

# %%
df.fillna(df['Star Rating'].value_counts().index[0], inplace = True)

# %%
df['Star Rating'] = df['Star Rating'].astype('int8')
df['Star Rating']
# Out:
# 0     4
# 1     4
# 2     3
# 3     4
# 4     4
#      ..
# 69    5
# 70    4
# 71    4
# 72    4
# 73    4
# Name: Star Rating, Length: 74, dtype: int8

# %%
df['Nearest Landmark']
# Out:
# 0            city centre
# 1            city centre
# 2     Attukal Waterfalls
# 3            city centre
# 4     Attukal Waterfalls
#              ...
# 69           city centre
# 70           city centre
# 71           city centre
# 72           city centre
# 73    Attukal Waterfalls
# Name: Nearest Landmark, Length: 74, dtype: object

# %%
df['Star Rating'].value_counts()
# Out:
# 4    40
# 3    18
# 5    15
# 2     1
# Name: Star Rating, dtype: int64

# %%
sys.getsizeof(df)
# Out:
# 36436

# %%
df['Rating Description'].value_counts()
# Out:
# Very Good    43
# Excellent    25
# Good          5
# Average       1
# Name: Rating Description, dtype: int64

# %%
df['Reviews']
# Out:
# 0     1058
# 1     1088
# 2      322
# 3     1337
# 4     1058
#       ...
# 69     292
# 70      17
# 71     395
# 72     187
# 73     221
# Name: Reviews, Length: 74, dtype: int64

# %%
print(type(df['Tax'].iloc[0]))
df['Tax'] = df['Tax'].apply(lambda x: str(x))
df['Tax'] = df['Tax'].apply(lambda x: x.replace(",",""))
df['Tax'] = df['Tax'].astype('float64')
df['Tax']
# Out:
# <class 'str'>
# 0      574.0
# 1      969.0
# 2      684.0
# 3      756.0
# 4      654.0
#        ...
# 69    2178.0
# 70     684.0
# 71     808.0
# 72    2124.0
# 73     223.0
# Name: Tax, Length: 74, dtype: float64

# %%
df['Tax'].fillna(df['Tax'].median(), inplace =True)

# %%
print(type(df['Star Rating'].iloc[0]))
df['Star Rating'] = df['Star Rating'].apply(lambda x: str(x))
df['Star Rating'] = df['Star Rating'].apply(lambda x: x.replace(",",""))
df['Star Rating'] = df['Star Rating'].astype('float64')
df['Star Rating']
# Out:
# <class 'numpy.int8'>
# 0     4.0
# 1     4.0
# 2     3.0
# 3     4.0
# 4     4.0
#      ...
# 69    5.0
# 70    4.0
# 71    4.0
# 72    4.0
# 73    4.0
# Name: Star Rating, Length: 74, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Hotel Name            74 non-null     object
#  1   Rating                74 non-null     float64
#  2   Rating Description    74 non-null     object
#  3   Reviews               74 non-null     int64
#  4   Star Rating           74 non-null     float64
#  5   Location              74 non-null     object
#  6   Nearest Landmark      74 non-null     object
#  7   Distance to Landmark  74 non-null     object
#  8   Price                 74 non-null     float64
#  9   Tax                   74 non-null     float64
#  10  unit                  74 non-null     object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 6.5+ KB

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7cf17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cf17_level0_col0" class="col_heading level0 col0" >Hotel Name</th>
#       <th id="T_7cf17_level0_col1" class="col_heading level0 col1" >Rating</th>
#       <th id="T_7cf17_level0_col2" class="col_heading level0 col2" >Rating Description</th>
#       <th id="T_7cf17_level0_col3" class="col_heading level0 col3" >Reviews</th>
#       <th id="T_7cf17_level0_col4" class="col_heading level0 col4" >Star Rating</th>
#       <th id="T_7cf17_level0_col5" class="col_heading level0 col5" >Location</th>
#       <th id="T_7cf17_level0_col6" class="col_heading level0 col6" >Nearest Landmark</th>
#       <th id="T_7cf17_level0_col7" class="col_heading level0 col7" >Distance to Landmark</th>
#       <th id="T_7cf17_level0_col8" class="col_heading level0 col8" >Price</th>
#       <th id="T_7cf17_level0_col9" class="col_heading level0 col9" >Tax</th>
#       <th id="T_7cf17_level0_col10" class="col_heading level0 col10" >unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cf17_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cf17_row0_col0" class="data row0 col0" >Gokulam Park</td>
#       <td id="T_7cf17_row0_col1" class="data row0 col1" >4.100000</td>
#       <td id="T_7cf17_row0_col2" class="data row0 col2" >Very Good</td>
#       <td id="T_7cf17_row0_col3" class="data row0 col3" >1058</td>
#       <td id="T_7cf17_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_7cf17_row0_col5" class="data row0 col5" >Chithirapuram </td>
#       <td id="T_7cf17_row0_col6" class="data row0 col6" >city centre</td>
#       <td id="T_7cf17_row0_col7" class="data row0 col7" >10.2</td>
#       <td id="T_7cf17_row0_col8" class="data row0 col8" >2728.000000</td>
#       <td id="T_7cf17_row0_col9" class="data row0 col9" >574.000000</td>
#       <td id="T_7cf17_row0_col10" class="data row0 col10" >km</td>
#     </tr>
#     <tr>
#       <th id="T_7cf17_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7cf17_row1_col0" class="data row1 col0" >Sterling Munnar</td>
#       <td id="T_7cf17_row1_col1" class="data row1 col1" >3.800000</td>
#       <td id="T_7cf17_row1_col2" class="data row1 col2" >Very Good</td>
#       <td id="T_7cf17_row1_col3" class="data row1 col3" >1088</td>
#       <td id="T_7cf17_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_7cf17_row1_col5" class="data row1 col5" >Chinnakanal </td>
#       <td id="T_7cf17_row1_col6" class="data row1 col6" >city centre</td>
#       <td id="T_7cf17_row1_col7" class="data row1 col7" >19.2</td>
#       <td id="T_7cf17_row1_col8" class="data row1 col8" >4451.000000</td>
#       <td id="T_7cf17_row1_col9" class="data row1 col9" >969.000000</td>
#       <td id="T_7cf17_row1_col10" class="data row1 col10" >km</td>
#     </tr>
#     <tr>
#       <th id="T_7cf17_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7cf17_row2_col0" class="data row2 col0" >Issacs Residency</td>
#       <td id="T_7cf17_row2_col1" class="data row2 col1" >4.100000</td>
#       <td id="T_7cf17_row2_col2" class="data row2 col2" >Very Good</td>
#       <td id="T_7cf17_row2_col3" class="data row2 col3" >322</td>
#       <td id="T_7cf17_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_7cf17_row2_col5" class="data row2 col5" >Central Munnar </td>
#       <td id="T_7cf17_row2_col6" class="data row2 col6" >Attukal Waterfalls</td>
#       <td id="T_7cf17_row2_col7" class="data row2 col7" >0.950000</td>
#       <td id="T_7cf17_row2_col8" class="data row2 col8" >2758.000000</td>
#       <td id="T_7cf17_row2_col9" class="data row2 col9" >684.000000</td>
#       <td id="T_7cf17_row2_col10" class="data row2 col10" >m</td>
#     </tr>
#     <tr>
#       <th id="T_7cf17_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7cf17_row3_col0" class="data row3 col0" >Tea Valley Resort</td>
#       <td id="T_7cf17_row3_col1" class="data row3 col1" >4.300000</td>
#       <td id="T_7cf17_row3_col2" class="data row3 col2" >Excellent</td>
#       <td id="T_7cf17_row3_col3" class="data row3 col3" >1337</td>
#       <td id="T_7cf17_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_7cf17_row3_col5" class="data row3 col5" >Pallivasal </td>
#       <td id="T_7cf17_row3_col6" class="data row3 col6" >city centre</td>
#       <td id="T_7cf17_row3_col7" class="data row3 col7" >4.8</td>
#       <td id="T_7cf17_row3_col8" class="data row3 col8" >2675.000000</td>
#       <td id="T_7cf17_row3_col9" class="data row3 col9" >756.000000</td>
#       <td id="T_7cf17_row3_col10" class="data row3 col10" >km</td>
#     </tr>
#     <tr>
#       <th id="T_7cf17_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7cf17_row4_col0" class="data row4 col0" >Grand Plaza</td>
#       <td id="T_7cf17_row4_col1" class="data row4 col1" >4.300000</td>
#       <td id="T_7cf17_row4_col2" class="data row4 col2" >Excellent</td>
#       <td id="T_7cf17_row4_col3" class="data row4 col3" >1058</td>
#       <td id="T_7cf17_row4_col4" class="data row4 col4" >4</td>
#       <td id="T_7cf17_row4_col5" class="data row4 col5" >Moolakadai </td>
#       <td id="T_7cf17_row4_col6" class="data row4 col6" >Attukal Waterfalls</td>
#       <td id="T_7cf17_row4_col7" class="data row4 col7" >1.9</td>
#       <td id="T_7cf17_row4_col8" class="data row4 col8" >3203.000000</td>
#       <td id="T_7cf17_row4_col9" class="data row4 col9" >654.000000</td>
#       <td id="T_7cf17_row4_col10" class="data row4 col10" >km</td>
#     </tr>
#     <tr>
#       <th id="T_7cf17_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7cf17_row5_col0" class="data row5 col0" >Misty Mountain Resort</td>
#       <td id="T_7cf17_row5_col1" class="data row5 col1" >4.200000</td>
#       <td id="T_7cf17_row5_col2" class="data row5 col2" >Very Good</td>
#       <td id="T_7cf17_row5_col3" class="data row5 col3" >1934</td>
#       <td id="T_7cf17_row5_col4" class="data row5 col4" >4</td>
#       <td id="T_7cf17_row5_col5" class="data row5 col5" >Pallivasal </td>
#       <td id="T_7cf17_row5_col6" class="data row5 col6" >city centre</td>
#       <td id="T_7cf17_row5_col7" class="data row5 col7" >7.5</td>
#       <td id="T_7cf17_row5_col8" class="data row5 col8" >3145.000000</td>
#       <td id="T_7cf17_row5_col9" class="data row5 col9" >848.000000</td>
#       <td id="T_7cf17_row5_col10" class="data row5 col10" >km</td>
#     </tr>
#     <tr>
#       <th id="T_7cf17_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7cf17_row6_col0" class="data row6 col0" >Eastend Munnar</td>
#       <td id="T_7cf17_row6_col1" class="data row6 col1" >3.900000</td>
#       <td id="T_7cf17_row6_col2" class="data row6 col2" >Very Good</td>
#       <td id="T_7cf17_row6_col3" class="data row6 col3" >437</td>
#       <td id="T_7cf17_row6_col4" class="data row6 col4" >4</td>
#       <td id="T_7cf17_row6_col5" class="data row6 col5" >Central Munnar </td>
#       <td id="T_7cf17_row6_col6" class="data row6 col6" >Attukal Waterfalls</td>
#       <td id="T_7cf17_row6_col7" class="data row6 col7" >0.770000</td>
#       <td id="T_7cf17_row6_col8" class="data row6 col8" >3493.000000</td>
#       <td id="T_7cf17_row6_col9" class="data row6 col9" >713.000000</td>
#       <td id="T_7cf17_row6_col10" class="data row6 col10" >m</td>
#     </tr>
#     <tr>
#       <th id="T_7cf17_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7cf17_row7_col0" class="data row7 col0" >Seven Springs Plantation Resort</td>
#       <td id="T_7cf17_row7_col1" class="data row7 col1" >3.700000</td>
#       <td id="T_7cf17_row7_col2" class="data row7 col2" >Very Good</td>
#       <td id="T_7cf17_row7_col3" class="data row7 col3" >6</td>
#       <td id="T_7cf17_row7_col4" class="data row7 col4" >3</td>
#       <td id="T_7cf17_row7_col5" class="data row7 col5" >Laxmi Estate </td>
#       <td id="T_7cf17_row7_col6" class="data row7 col6" >city centre</td>
#       <td id="T_7cf17_row7_col7" class="data row7 col7" >12.3</td>
#       <td id="T_7cf17_row7_col8" class="data row7 col8" >2255.000000</td>
#       <td id="T_7cf17_row7_c

# %%
def my_map(x, avg):
    if x < avg:
        return 'color: ' + 'red'
    else:
        return 'color: ' + 'green'

# %%
avg_val= df['Price'].mean()

# %%
df[['Price']].style.applymap(lambda x: my_map(x, avg_val))
# Out:
# <style type="text/css">
# #T_27206_row0_col0, #T_27206_row2_col0, #T_27206_row3_col0, #T_27206_row4_col0, #T_27206_row5_col0, #T_27206_row6_col0, #T_27206_row7_col0, #T_27206_row8_col0, #T_27206_row12_col0, #T_27206_row14_col0, #T_27206_row16_col0, #T_27206_row17_col0, #T_27206_row19_col0, #T_27206_row20_col0, #T_27206_row21_col0, #T_27206_row23_col0, #T_27206_row28_col0, #T_27206_row29_col0, #T_27206_row30_col0, #T_27206_row31_col0, #T_27206_row32_col0, #T_27206_row33_col0, #T_27206_row34_col0, #T_27206_row35_col0, #T_27206_row37_col0, #T_27206_row39_col0, #T_27206_row40_col0, #T_27206_row41_col0, #T_27206_row43_col0, #T_27206_row44_col0, #T_27206_row46_col0, #T_27206_row47_col0, #T_27206_row48_col0, #T_27206_row49_col0, #T_27206_row50_col0, #T_27206_row51_col0, #T_27206_row52_col0, #T_27206_row55_col0, #T_27206_row56_col0, #T_27206_row57_col0, #T_27206_row58_col0, #T_27206_row61_col0, #T_27206_row62_col0, #T_27206_row63_col0, #T_27206_row65_col0, #T_27206_row66_col0, #T_27206_row67_col0, #T_27206_row68_col0, #T_27206_row70_col0, #T_27206_row71_col0, #T_27206_row73_col0 {
#   color: red;
# }
# #T_27206_row1_col0, #T_27206_row9_col0, #T_27206_row10_col0, #T_27206_row11_col0, #T_27206_row13_col0, #T_27206_row15_col0, #T_27206_row18_col0, #T_27206_row22_col0, #T_27206_row24_col0, #T_27206_row25_col0, #T_27206_row26_col0, #T_27206_row27_col0, #T_27206_row36_col0, #T_27206_row38_col0, #T_27206_row42_col0, #T_27206_row45_col0, #T_27206_row53_col0, #T_27206_row54_col0, #T_27206_row59_col0, #T_27206_row60_col0, #T_27206_row64_col0, #T_27206_row69_col0, #T_27206_row72_col0 {
#   color: green;
# }
# </style>
# <table id="T_27206">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27206_level0_col0" class="col_heading level0 col0" >Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27206_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27206_row0_col0" class="data row0 col0" >2728.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27206_row1_col0" class="data row1 col0" >4451.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27206_row2_col0" class="data row2 col0" >2758.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27206_row3_col0" class="data row3 col0" >2675.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_27206_row4_col0" class="data row4 col0" >3203.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_27206_row5_col0" class="data row5 col0" >3145.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_27206_row6_col0" class="data row6 col0" >3493.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_27206_row7_col0" class="data row7 col0" >2255.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_27206_row8_col0" class="data row8 col0" >2595.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_27206_row9_col0" class="data row9 col0" >5583.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_27206_row10_col0" class="data row10 col0" >5022.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_27206_row11_col0" class="data row11 col0" >9977.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_27206_row12_col0" class="data row12 col0" >2494.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_27206_row13_col0" class="data row13 col0" >4815.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_27206_row14_col0" class="data row14 col0" >966.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_27206_row15_col0" class="data row15 col0" >7905.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_27206_row16_col0" class="data row16 col0" >1279.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_27206_row17_col0" class="data row17 col0" >3481.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_27206_row18_col0" class="data row18 col0" >11974.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_27206_row19_col0" class="data row19 col0" >2820.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_27206_row20_col0" class="data row20 col0" >1791.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_27206_row21_col0" class="data row21 col0" >1545.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_27206_row22_col0" class="data row22 col0" >7784.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_27206_row23_col0" class="data row23 col0" >2364.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_27206_row24_col0" class="data row24 col0" >5661.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_27206_row25_col0" class="data row25 col0" >5204.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_27206_row26_col0" class="data row26 col0" >4910.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_27206_row27_col0" class="data row27 col0" >9000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_27206_row28_col0" class="data row28 col0" >3320.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_27206_row29_col0" class="data row29 col0" >3974.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_27206_row30_col0" class="data row30 col0" >2410.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row31" class="row_heading level0 row31" >31</th>
#       <td id="T_27206_row31_col0" class="data row31 col0" >978.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row32" class="row_heading level0 row32" >32</th>
#       <td id="T_27206_row32_col0" class="data row32 col0" >1674.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row33" class="row_heading level0 row33" >33</th>
#       <td id="T_27206_row33_col0" class="data row33 col0" >930.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row34" class="row_heading level0 row34" >34</th>
#       <td id="T_27206_row34_col0" class="data row34 col0" >2832.000000</td>
#     </tr>
#     <tr>
#       <th id="T_27206_level0_row35" class="row_heading level0 row35" >35</th>
#       <td id="T_27206_row35_col0" class="data row35 col0" >3629.000000</td>
#     </tr>
#     <tr>
#       <t

# %%
df.style.highlight_max(color= 'green').highlight_min(color= 'yellow')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _repr_html_(self)
#     270         """
#     271         if get_option("styler.render.repr") == "html":
# --> 272             return self.to_html()
#     273         return None
#     274
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1177
#    1178         # Build HTML string..
# -> 1179         html = obj._render_html(
#    1180             sparse_index=sparse_index,
#    1181             sparse_columns=sparse_columns,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style_render.py in _render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     160         Generates a dict with necessary kwargs passed to jinja2 template.
#     161         """
# --> 162         self._compute()
#     163         # TODO: namespace all the pandas keys
#     164         d = self._translate(sparse_index, sparse_columns, max_rows, max_cols)
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style_render.py in _compute(self)
#     203         r = self
#     204         for func, args, kwargs in self._todo:
# --> 205             r = func(self)(*args, **kwargs)
#     206         return r
#     207
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _apply(self, func, axis, subset, **kwargs)
#    1440             axis = self.data._get_axis_number(axis)
#    1441             if axis == 0:
# -> 1442                 result = data.apply(func, axis=0, **kwargs)
#    1443             else:
#    1444                 result = data.T.apply(func, axis=0, **kwargs).T  # see GH 42005
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
#     859         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     871             for i, v in enumerate(series_gen):
#     872                 # ignore SettingWithCopy here in case the user mutates
# --> 873                 results[i] = self.f(v)
#     874                 if isinstance(results[i], ABCSeries):
#     875                     # If we have a view on v, we need to make a copy because
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in f(x)
#     136
#     137             def f(x):
# --> 138                 return func(x, *args, **kwargs)
#     139
#     140         else:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _highlight_value(data, op, props)
#    3658     Return an array of css strings based on the condition of values matching an op.
#    3659     """
# -> 3660     value = getattr(data, op)(skipna=True)
#    3661     if isinstance(data, DataFrame):  # min/max must be done twice to return scalar
#    3662         value = getattr(value, op)(skipna=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   11217             **kwargs,
#   11218         ):
# > 11219             return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11220
#   11221         setattr(cls, "max", max)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   10674         **kwargs,
#   10675     ):
# > 10676         return self._stat_function(
#   10677             "max",
#   10678             nanops.nanmax,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10644                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10645             )
# > 10646         return self._reduce(
#   10647             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10648         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4469                 )
#    4470             with np.errstate(all="ignore"):
# -> 4471                 return op(delegate, skipna=skipna, **kwds)
#    4472
#    4473     def _reindex_indexer(
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     408             mask = isna(values)
#     409
# --> 410         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     411
#     412         if datetimelike:
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna, mask)
#    1041                 result = np.nan
#    1042         else:
# -> 1043             result = getattr(values, meth)(axis)
#    1044
#    1045         result = _maybe_null_out(result, axis, mask, values.shape)
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      38 def _amax(a, axis=None, out=None, keepdims=False,
#      39           initial=_NoValue, where=True):
# ---> 40     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      41
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#
# TypeError: '>=' not supported between instances of 'str' and 'float'

# %%
df.style.background_gradient(cmap= 'Reds')
# Out:
# <style type="text/css">
# #T_ad08b_row0_col1, #T_ad08b_row2_col1, #T_ad08b_row9_col1, #T_ad08b_row37_col1, #T_ad08b_row53_col1, #T_ad08b_row66_col1, #T_ad08b_row69_col8, #T_ad08b_row70_col1, #T_ad08b_row72_col1 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_ad08b_row0_col3, #T_ad08b_row4_col3 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_ad08b_row0_col4, #T_ad08b_row1_col4, #T_ad08b_row3_col4, #T_ad08b_row4_col4, #T_ad08b_row5_col4, #T_ad08b_row6_col4, #T_ad08b_row8_col4, #T_ad08b_row10_col4, #T_ad08b_row12_col4, #T_ad08b_row14_col4, #T_ad08b_row16_col4, #T_ad08b_row17_col4, #T_ad08b_row19_col4, #T_ad08b_row21_col4, #T_ad08b_row25_col4, #T_ad08b_row26_col4, #T_ad08b_row28_col4, #T_ad08b_row29_col4, #T_ad08b_row30_col4, #T_ad08b_row31_col4, #T_ad08b_row33_col4, #T_ad08b_row34_col4, #T_ad08b_row35_col4, #T_ad08b_row42_col4, #T_ad08b_row46_col4, #T_ad08b_row47_col4, #T_ad08b_row48_col4, #T_ad08b_row52_col4, #T_ad08b_row53_col4, #T_ad08b_row56_col4, #T_ad08b_row57_col4, #T_ad08b_row58_col4, #T_ad08b_row59_col4, #T_ad08b_row61_col4, #T_ad08b_row64_col4, #T_ad08b_row68_col4, #T_ad08b_row70_col4, #T_ad08b_row71_col4, #T_ad08b_row72_col4, #T_ad08b_row73_col4 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_ad08b_row0_col8, #T_ad08b_row2_col3, #T_ad08b_row3_col9, #T_ad08b_row43_col8 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_ad08b_row0_col9, #T_ad08b_row46_col9, #T_ad08b_row65_col3 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_ad08b_row1_col1, #T_ad08b_row20_col1, #T_ad08b_row25_col1, #T_ad08b_row39_col1 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_ad08b_row1_col3 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_ad08b_row1_col8 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_ad08b_row1_col9, #T_ad08b_row67_col8 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_ad08b_row2_col4, #T_ad08b_row7_col4, #T_ad08b_row20_col4, #T_ad08b_row23_col4, #T_ad08b_row32_col4, #T_ad08b_row37_col4, #T_ad08b_row39_col4, #T_ad08b_row40_col4, #T_ad08b_row41_col4, #T_ad08b_row43_col4, #T_ad08b_row44_col4, #T_ad08b_row49_col4, #T_ad08b_row50_col4, #T_ad08b_row51_col4, #T_ad08b_row62_col4, #T_ad08b_row65_col4, #T_ad08b_row66_col4, #T_ad08b_row67_col4 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_ad08b_row2_col8, #T_ad08b_row41_col8, #T_ad08b_row68_col3 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_ad08b_row2_col9, #T_ad08b_row28_col9, #T_ad08b_row34_col3, #T_ad08b_row37_col8, #T_ad08b_row69_col3, #T_ad08b_row70_col9 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_ad08b_row3_col1, #T_ad08b_row4_col1, #T_ad08b_row11_col1, #T_ad08b_row41_col1, #T_ad08b_row45_col1, #T_ad08b_row60_col1, #T_ad08b_row61_col1, #T_ad08b_row71_col1 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_ad08b_row3_col3 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_ad08b_row3_col8, #T_ad08b_row50_col8, #T_ad08b_row51_col9 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_ad08b_row4_col8, #T_ad08b_row17_col9, #T_ad08b_row55_col9 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_ad08b_row4_col9, #T_ad08b_row12_col8, #T_ad08b_row41_col9, #T_ad08b_row67_col9 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_ad08b_row5_col1, #T_ad08b_row14_col1, #T_ad08b_row17_col1, #T_ad08b_row22_col1, #T_ad08b_row26_col1, #T_ad08b_row34_col1, #T_ad08b_row35_col1, #T_ad08b_row50_col1, #T_ad08b_row51_col1, #T_ad08b_row57_col1, #T_ad08b_row58_col1 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_ad08b_row5_col3, #T_ad08b_row9_col4, #T_ad08b_row11_col4, #T_ad08b_row13_col4, #T_ad08b_row15_col4, #T_ad08b_row18_col4, #T_ad08b_row18_col8, #T_ad08b_row18_col9, #T_ad08b_row22_col4, #T_ad08b_row24_col4, #T_ad08b_row27_col1, #T_ad08b_row27_col4, #T_ad08b_row36_col4, #T_ad08b_row38_col4, #T_ad08b_row45_col4, #T_ad08b_row54_col4, #T_ad08b_row55_col4, #T_ad08b_row60_col4, #T_ad08b_row69_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ad08b_row5_col8, #T_ad08b_row39_col9, #T_ad08b_row51_col3, #T_ad08b_row53_col9, #T_ad08b_row71_col3, #T_ad08b_row73_col1 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_ad08b_row5_col9, #T_ad08b_row27_col3, #T_ad08b_row44_col8, #T_ad08b_row68_col9 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_ad08b_row6_col1, #T_ad08b_row13_col1, #T_ad08b_row19_col1, #T_ad08b_row21_col1, #T_ad08b_row23_col1, #T_ad08b_row33_col1, #T_ad08b_row45_col9, #T_ad08b_row46_col1, #T_ad08b_row47_col1, #T_ad08b_row48_col1 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_ad08b_row6_col3, #T_ad08b_row55_col8, #T_ad08b_row61_col3 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_ad08b_row6_col8, #T_ad08b_row17_col8 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_ad08b_row6_col9, #T_ad08b_row40_col3, #T_ad08b_row40_col9, #T_ad08b_row49_col8 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_ad08b_row7_col1, #T_ad08b_row22_col9, #T_ad08b_row59_col1 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_ad08b_row7_col3, #T_ad08b_row14_col8, #T_ad08b_row25_col3, #T_ad08b_row26_col9, #T_ad08b_row27_col9, #T_ad08b_row31_col1, #T_ad08b_row33_col8, #T_ad08b_row63_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_ad08b_row7_col8, #T_ad08b_row7_col9, #T_ad08b_row36_col3, #T_ad08b_row46_col8, #T_ad08b_row49_col9, #T_ad08b_row63_col3 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_ad08b_row8_col1, #T_ad08b_row28_col1, #T_ad08b_row44_col1, #T_ad08b_row55_col1 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_ad08b_row8_col3 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_ad08b_row8_col8, #T_ad08b_row19_col9, #T_ad08b_row43_col1, #T_ad08b_row49_col1 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_ad08b_row8_col9, #T_ad08b_row38_col3, #T_ad08b_row48_col3 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_ad08b_row9_col3, #T_ad08b_row23_col9, #T_ad08b_row30_col9, #T_ad08b_row31_col3, #T_ad08b_row43_col9 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_ad08b_row9_col8 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_ad08b_row9_col9 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_ad08b_row10_col1, #T_ad08b_row24_col1, #T_ad08b_row29_col1, #T_ad08b_row42_col1, #T_ad08b_row52_col1 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_ad08b_row10_col3 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_ad08b_row10_col8 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_ad08b_row10_col9, #T_ad08b_row13_col3, #T_ad08b_row57_col8 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_ad08b_row11_col3 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_ad08b_row11_col8 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# #T_ad08b_row11_col9 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_ad08b_row12_col1, #T_ad08b_row16_col1, #T_ad08b_row38_col1, #T_ad08b_row68_col1, #T_ad08b_row69_col1 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_ad08b_row12_col3, #T_ad08b_row55_col3, #T_ad08b_row56_col9 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_ad08b_row12_col9, #T_ad08b_row30_col8, #T_ad08b_row40_col8 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_ad08b_row13_col8 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_ad08b_row13_col9, #T_ad08b_row19_col3 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_ad08b_row14_col3, #T_ad08b_row34_col9 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_ad08b_row14_col9, #T_ad08b_row49_col3, #T_ad08b_row57_col3, #T_ad08b_row67_col3, #T_ad08b_row73_col9 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_ad08b_row15_col1, #T_ad08b_row18_col1, #T_ad08b_row36_col1, #T_ad08b_row36_col8, #T_ad08b_row54_col1 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_ad08b_row15_col3, #T_ad08b_row32_col8, #T_ad08b_row62_col8 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_ad08b_row15_col8 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_ad08b_row15_col9 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_ad08b_row16_col3, #T_ad08b_row17_col3, #T_ad08b_row58_col9, #T_ad08b_row59_col3, #T_ad08b_row66_col3,

# %%
df[['Price', 'Tax', 'Rating', 'Reviews']].style.bar()
# Out:
# <style type="text/css">
# #T_7387f_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.8%, transparent 22.8%);
# }
# #T_7387f_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.4%, transparent 12.4%);
# }
# #T_7387f_row0_col2, #T_7387f_row2_col2, #T_7387f_row9_col2, #T_7387f_row37_col2, #T_7387f_row53_col2, #T_7387f_row66_col2, #T_7387f_row70_col2, #T_7387f_row72_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 85.4%, transparent 85.4%);
# }
# #T_7387f_row0_col3, #T_7387f_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.7%, transparent 54.7%);
# }
# #T_7387f_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.2%, transparent 37.2%);
# }
# #T_7387f_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.0%, transparent 21.0%);
# }
# #T_7387f_row1_col2, #T_7387f_row20_col2, #T_7387f_row25_col2, #T_7387f_row39_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 79.2%, transparent 79.2%);
# }
# #T_7387f_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.3%, transparent 56.3%);
# }
# #T_7387f_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 23.0%, transparent 23.0%);
# }
# #T_7387f_row2_col1, #T_7387f_row70_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.8%, transparent 14.8%);
# }
# #T_7387f_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.6%, transparent 16.6%);
# }
# #T_7387f_row3_col0, #T_7387f_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.3%, transparent 22.3%);
# }
# #T_7387f_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.4%, transparent 16.4%);
# }
# #T_7387f_row3_col2, #T_7387f_row4_col2, #T_7387f_row11_col2, #T_7387f_row41_col2, #T_7387f_row45_col2, #T_7387f_row60_col2, #T_7387f_row61_col2, #T_7387f_row71_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.6%, transparent 89.6%);
# }
# #T_7387f_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.1%, transparent 69.1%);
# }
# #T_7387f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.7%, transparent 26.7%);
# }
# #T_7387f_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.2%, transparent 14.2%);
# }
# #T_7387f_row5_col0, #T_7387f_row24_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.3%, transparent 26.3%);
# }
# #T_7387f_row5_col1, #T_7387f_row27_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.4%, transparent 18.4%);
# }
# #T_7387f_row5_col2, #T_7387f_row14_col2, #T_7387f_row17_col2, #T_7387f_row22_col2, #T_7387f_row26_col2, #T_7387f_row34_col2, #T_7387f_row35_col2, #T_7387f_row50_col2, #T_7387f_row51_col2, #T_7387f_row57_col2, #T_7387f_row58_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.5%, transparent 87.5%);
# }
# #T_7387f_row5_col3, #T_7387f_row18_col0, #T_7387f_row18_col1, #T_7387f_row27_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_7387f_row6_col0, #T_7387f_row42_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.2%, transparent 29.2%);
# }
# #T_7387f_row6_col1, #T_7387f_row40_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.4%, transparent 15.4%);
# }
# #T_7387f_row6_col2, #T_7387f_row13_col2, #T_7387f_row19_col2, #T_7387f_row21_col2, #T_7387f_row23_col2, #T_7387f_row33_col2, #T_7387f_row46_col2, #T_7387f_row47_col2, #T_7387f_row48_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.2%, transparent 81.2%);
# }
# #T_7387f_row6_col3, #T_7387f_row43_col0, #T_7387f_row61_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.6%, transparent 22.6%);
# }
# #T_7387f_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.8%, transparent 18.8%);
# }
# #T_7387f_row7_col1, #T_7387f_row63_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.0%, transparent 12.0%);
# }
# #T_7387f_row7_col2, #T_7387f_row59_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.1%, transparent 77.1%);
# }
# #T_7387f_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.3%, transparent 0.3%);
# }
# #T_7387f_row8_col0, #T_7387f_row45_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.7%, transparent 21.7%);
# }
# #T_7387f_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.5%, transparent 11.5%);
# }
# #T_7387f_row8_col2, #T_7387f_row11_col0, #T_7387f_row28_col2, #T_7387f_row44_col2, #T_7387f_row55_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 83.3%, transparent 83.3%);
# }
# #T_7387f_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 31.0%, transparent 31.0%);
# }
# #T_7387f_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.6%, transparent 46.6%);
# }
# #T_7387f_row9_col1, #T_7387f_row32_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.7%, transparent 24.7%);
# }
# #T_7387f_row9_col3, #T_7387f_row21_col0, #T_7387f_row30_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.9%, transparent 12.9%);
# }
# #T_7387f_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 41.9%, transparent 41.9%);
# }
# #T_7387f_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.2%, transparent 22.2%);
# }
# #T_7387f_row10_col2, #T_7387f_row24_col2, #T_7387f_row29_col2, #T_7387f_row42_col2, #T_7387f_row52_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.7%, transparent 91.7%);
# }
# #T_7387f_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.0%, transparent 44.0%);
# }
# #T_7387f_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.1%, transparent 58.1%);
# }
# #T_7387f_row11_col3, #T_7387f_row69_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.7%, transparent 67.7%);
# }
# #T_7387f_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.8%, transparent 20.8%);
# }
# #T_7387f_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.7%, transparent 13.7%);
# }
# #T_7387f_row12_col2, #T_7387f_row16_col2, #T_7387f_row38_col2, #T_7387f_row68_col2, #T_7387f_row69_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.8%, transparent 93.8%);
# }
# #T_7387f_row12_col3, #T_7387f_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.0%, transparent 5.0%);
# }
# #T_7387f_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.2%, transparent 40.2%);
# }
# #T_7387f_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.5%, transparent 25.5%);
# }
# #T_7387f_row14_col0, #T_7387f_row20_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.1%, transparent 8.1%);
# }
# #T_7387f_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.1%, transparent 19.1%);
# }
# #T_7387f_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 66.0%, transparent 66.0%);
# }
# #T_7387f_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.5%, transparent 51.5%);
# }
# #T_7387f_row15_col2, #T_7387f_row18_col2, #T_7387f_row36_col2, #T_7387f_row54_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.8%, transparent 95.8%);
# }
# #T_7387f_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.0%, transparent 7.0%);
# }
# #T_7387f_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.7%, transparent 10.7%);
# }
# #T_7387f_row16_col1, #T_7387f_row30_col3, #T_7387f_row50_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.8%, transparent 5.8%);
# }
# #T_7387f_row16_col3, #T_7387f_row17_col3, #T_7387f_row72_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.7%, transparent 9.7%);
# }
# #T_7387f_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.1%, transparent 29.1%);
# }
# #T_7387f_row1

# %%
df[['Price', 'Rating', 'Tax', 'Reviews']].style.bar(subset =['Price'], color= 'red').bar(subset =['Rating'], color = 'blue').bar(subset =['Tax'], color = 'green').bar(subset =['Reviews'], color = 'pink')
# Out:
# <style type="text/css">
# #T_08491_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 22.8%, transparent 22.8%);
# }
# #T_08491_row0_col1, #T_08491_row2_col1, #T_08491_row9_col1, #T_08491_row37_col1, #T_08491_row53_col1, #T_08491_row66_col1, #T_08491_row70_col1, #T_08491_row72_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 85.4%, transparent 85.4%);
# }
# #T_08491_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 12.4%, transparent 12.4%);
# }
# #T_08491_row0_col3, #T_08491_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 54.7%, transparent 54.7%);
# }
# #T_08491_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 37.2%, transparent 37.2%);
# }
# #T_08491_row1_col1, #T_08491_row20_col1, #T_08491_row25_col1, #T_08491_row39_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 79.2%, transparent 79.2%);
# }
# #T_08491_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 21.0%, transparent 21.0%);
# }
# #T_08491_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 56.3%, transparent 56.3%);
# }
# #T_08491_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 23.0%, transparent 23.0%);
# }
# #T_08491_row2_col2, #T_08491_row70_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 14.8%, transparent 14.8%);
# }
# #T_08491_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 16.6%, transparent 16.6%);
# }
# #T_08491_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 22.3%, transparent 22.3%);
# }
# #T_08491_row3_col1, #T_08491_row4_col1, #T_08491_row11_col1, #T_08491_row41_col1, #T_08491_row45_col1, #T_08491_row60_col1, #T_08491_row61_col1, #T_08491_row71_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 89.6%, transparent 89.6%);
# }
# #T_08491_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 16.4%, transparent 16.4%);
# }
# #T_08491_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 69.1%, transparent 69.1%);
# }
# #T_08491_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 26.7%, transparent 26.7%);
# }
# #T_08491_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 14.2%, transparent 14.2%);
# }
# #T_08491_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 26.3%, transparent 26.3%);
# }
# #T_08491_row5_col1, #T_08491_row14_col1, #T_08491_row17_col1, #T_08491_row22_col1, #T_08491_row26_col1, #T_08491_row34_col1, #T_08491_row35_col1, #T_08491_row50_col1, #T_08491_row51_col1, #T_08491_row57_col1, #T_08491_row58_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 87.5%, transparent 87.5%);
# }
# #T_08491_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 18.4%, transparent 18.4%);
# }
# #T_08491_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 100.0%, transparent 100.0%);
# }
# #T_08491_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 29.2%, transparent 29.2%);
# }
# #T_08491_row6_col1, #T_08491_row13_col1, #T_08491_row19_col1, #T_08491_row21_col1, #T_08491_row23_col1, #T_08491_row33_col1, #T_08491_row46_col1, #T_08491_row47_col1, #T_08491_row48_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 81.2%, transparent 81.2%);
# }
# #T_08491_row6_col2, #T_08491_row40_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 15.4%, transparent 15.4%);
# }
# #T_08491_row6_col3, #T_08491_row61_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 22.6%, transparent 22.6%);
# }
# #T_08491_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 18.8%, transparent 18.8%);
# }
# #T_08491_row7_col1, #T_08491_row59_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 77.1%, transparent 77.1%);
# }
# #T_08491_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 12.0%, transparent 12.0%);
# }
# #T_08491_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 0.3%, transparent 0.3%);
# }
# #T_08491_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 21.7%, transparent 21.7%);
# }
# #T_08491_row8_col1, #T_08491_row28_col1, #T_08491_row44_col1, #T_08491_row55_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 83.3%, transparent 83.3%);
# }
# #T_08491_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 11.5%, transparent 11.5%);
# }
# #T_08491_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 31.0%, transparent 31.0%);
# }
# #T_08491_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 46.6%, transparent 46.6%);
# }
# #T_08491_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 24.7%, transparent 24.7%);
# }
# #T_08491_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 12.9%, transparent 12.9%);
# }
# #T_08491_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 41.9%, transparent 41.9%);
# }
# #T_08491_row10_col1, #T_08491_row24_col1, #T_08491_row29_col1, #T_08491_row42_col1, #T_08491_row52_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 91.7%, transparent 91.7%);
# }
# #T_08491_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 22.2%, transparent 22.2%);
# }
# #T_08491_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 44.0%, transparent 44.0%);
# }
# #T_08491_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 83.3%, transparent 83.3%);
# }
# #T_08491_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 58.1%, transparent 58.1%);
# }
# #T_08491_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 67.7%, transparent 67.7%);
# }
# #T_08491_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 20.8%, transparent 20.8%);
# }
# #T_08491_row12_col1, #T_08491_row16_col1, #T_08491_row38_col1, #T_08491_row68_col1, #T_08491_row69_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 93.8%, transparent 93.8%);
# }
# #T_08491_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 13.7%, transparent 13.7%);
# }
# #T_08491_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 5.0%, transparent 5.0%);
# }
# #T_08491_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 40.2%, transparent 40.2%);
# }
# #T_08491_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 25.5%, transparent 25.5%);
# }
# #T_08491_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 22.3%, transparent 22.3%);
# }
# #T_08491_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 8.1%, transparent 8.1%);
# }
# #T_08491_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 5.0%, transparent 5.0%);
# }
# #T_08491_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 19.1%, transparent 19.1%);
# }
# #T_08491_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 66.0%, transparent 66.0%);
# }
# #T_08491_row15_col1, #T_08491_row18_col1, #T_08491_row36_col1, #T_08491_row54_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, blue 95.8%, transparent 95.8%);
# }
# #T_08491_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 51.5%, transparent 51.5%);
# }
# #T_08491_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 7.0%, transparent 7.0%);
# }
# #T_08491_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 10.7%, transparent 10.7%);
# }
# #T_08491_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 5.8%, transparent 5.8%);
# }
# #T_08491_row16_col3, #T_08491_row17_col3, #T_08491_row72_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, pink 9.7%, transparent 9.7%);
# }
# #T_08491_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 29.1%, transparent 29.1%);
# }
# #T_08491_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, green 20.5%, transparent 20.5%);
# }
# #T_08491_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 100.0%, transparent 100.0%);
# }
# #T_08491_row18_col2 {
#   width: 10em;
#   backgrou

# %%
for j,i in enumerate(df.columns):
    if df[i].dtype == 'float':
        plt.figure(j)
        sns.histplot(df[i], kde= False)

# %%
sns.boxplot(x = df['Price'], orient = 'h')
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.boxplot(x = df['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
fig_x_y= df.groupby('Rating')['Rating'].count()
sns.barplot(x= fig_x_y.index, y= fig_x_y.values)
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
fig_x_y= df.groupby('Rating Description')['Rating Description'].count()
sns.barplot(x= fig_x_y.index, y=fig_x_y.values)
# Out:
# <AxesSubplot:xlabel='Rating Description'>

# %%
rating_desc= df['Rating Description'].unique()
def rating_to_nums(i):
    if i == 'Good':
        return 1
    elif i =='Average':
        return 0
    elif i =='Very Good':
        return 2
    elif i =='Excellent':
        return 3

# %%
df['Rating Description_numeric']= df['Rating Description'].apply(lambda x: rating_to_nums(x))
fig_x_y= df.groupby('Rating Description_numeric')['Rating Description_numeric'].count()
sns.barplot(x= fig_x_y.index, y=fig_x_y.values)
# Out:
# <AxesSubplot:xlabel='Rating Description_numeric'>

# %%
df['Rating Description'].apply(lambda x: rating_to_nums(x))
# Out:
# 0     2
# 1     2
# 2     2
# 3     3
# 4     3
#      ..
# 69    3
# 70    2
# 71    3
# 72    2
# 73    1
# Name: Rating Description, Length: 74, dtype: int64

# %%
df['Rating Description']
# Out:
# 0     Very Good
# 1     Very Good
# 2     Very Good
# 3     Excellent
# 4     Excellent
#         ...
# 69    Excellent
# 70    Very Good
# 71    Excellent
# 72    Very Good
# 73         Good
# Name: Rating Description, Length: 74, dtype: object

# %%
sns.jointplot(x= df['Rating'], y = df['Price'])

# %%
sns.jointplot(x= df['Reviews'], y = df['Price'])

# %%
sns.relplot(
    data=df,
    x='Price', y= 'Reviews',
    size='Rating', sizes=(10, 100),
    hue='Rating',
    palette='rainbow',
);

# %%
sns.boxplot(x= 'Price', y = 'Rating Description', data = df)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Rating Description'>

# %%
sns.violinplot(x= 'Price', y = 'Rating Description', data = df)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Rating Description'>

# %%
sns.violinplot(x= 'Price', y = 'Rating Description', data = df, hue = 'Nearest Landmark')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Rating Description'>

# %%
sns.violinplot(x= 'Price', y = 'Rating Description', data = df, hue = 'Nearest Landmark',palette = 'inferno', split = True) #3D violin plots
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Rating Description'>

# %%
fig_x_y= df.groupby('Rating Description')['Rating Description'].count()
plt.pie(fig_x_y, labels= fig_x_y.index, autopct = '%.2f', explode = [0,1,0,0])
plt.show()

# %%
fig_x_y_lm= df.groupby('Nearest Landmark')['Nearest Landmark'].count()
plt.pie(fig_x_y, labels= fig_x_y.index, autopct = '%.2f', wedgeprops= {'width': 0.8}, radius = 2, labeldistance= 1)
plt.pie(fig_x_y_lm, labels= fig_x_y_lm.index, autopct = '%.2f', wedgeprops= {'width': 0.5}, radius = 1, labeldistance= 0.1)
plt.show()
